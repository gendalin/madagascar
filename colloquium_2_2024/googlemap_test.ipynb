# %%
from pprint import pprint
import googlemaps

# %%
API_KEY = "AIzaSyDmEKyh2vbQH3LxUecB-nFtRfq2Ek5p2Lk"

# %%
try:
    location = {'lat': 40.69414898856889, 'lng': -73.9061565}
except NameError:
    print("Error: 'response' is not defined. Please ensure the geocode response is available.")

else:
    places_result = map_client.places_nearby(
        location=location,
        type='restaurant',
        rank_by='distance'
    )

    restaurants = places_result.get('results', [])[:25]  # Get the nearest 25 restaurants

    for i, restaurant in enumerate(restaurants, start=1):
        name = restaurant.get('name')
        address = restaurant.get('vicinity')
        print(f"{i}. {name} - {address}")
# Out:
# 1. Los Limones Deli - 1330 Halsey Street, Brooklyn
# 2. Dunkin' - 1379 Halsey Street, Brooklyn
# 3. Golden Thai - 469 Irving Avenue, Brooklyn
# 4. Bushwick Taco Company - 839 Knickerbocker Avenue, Brooklyn
# 5. Number One - 824 Knickerbocker Avenue, Brooklyn
# 6. Bill's - 985 Wyckoff Avenue, Ridgewood
# 7. Hong Kong Express - 989 Wyckoff Avenue, Ridgewood
# 8. C&B Luncheonette - 983 Wyckoff Avenue, Ridgewood
# 9. Cafe Rum - 10-50 Wyckoff Avenue, Ridgewood
# 10. Bombay Kitchen - 733 Knickerbocker Avenue, Brooklyn
# 11. Doozie’s pizza - 1616 George Street, Queens
# 12. Lopez Bar Restaurant - 856 Knickerbocker Avenue, Brooklyn
# 13. El Novillo 2 - 1069 Wyckoff Avenue, Flushing
# 14. Nhà Mình - 915 Wyckoff Avenue, Ridgewood
# 15. 888 Pizza - 888 Wyckoff Avenue, Brooklyn
# 16. Trans-Pecos - 9-15 Wyckoff Avenue, Ridgewood
# 17. pàn - 1563 Decatur Street, Ridgewood
# 18. Everyday Chinese - 890 Wyckoff Avenue, Brooklyn
# 19. Palace of Zuly - 913 Wyckoff Avenue, Ridgewood
# ...

# %%
for i, restaurant in enumerate(restaurants, start=1):
    name = restaurant.get('name')
    address = restaurant.get('vicinity')
    
    # Fetch business details to get opening hours
    place_id = restaurant.get('place_id')
    details = map_client.place(place_id=place_id, fields=['opening_hours'])
    opening_hours = details.get('result', {}).get('opening_hours', {}).get('weekday_text', 'No hours available')
    
    print(f"{i}. {name} - {address}")
    if isinstance(opening_hours, list):
        for hours in opening_hours:
            # Extract and print only the end hour
            end_hour = hours.split('–')[-1].strip() if '–' in hours else 'No end hour available'
            print(f"   End Hour: {end_hour}")
    else:
        print(f"   {opening_hours}")
# Out:
# 1. Los Limones Deli - 1330 Halsey Street, Brooklyn
#    End Hour: 12:00 AM
#    End Hour: 12:00 AM
#    End Hour: 12:00 AM
#    End Hour: 12:00 AM
#    End Hour: 12:00 AM
#    End Hour: 12:00 AM
#    End Hour: 11:00 PM
# 2. Dunkin' - 1379 Halsey Street, Brooklyn
#    End Hour: 9:00 PM
#    End Hour: 9:00 PM
#    End Hour: 9:00 PM
#    End Hour: 9:00 PM
#    End Hour: 9:00 PM
#    End Hour: 9:00 PM
#    End Hour: 9:00 PM
# 3. Golden Thai - 469 Irving Avenue, Brooklyn
#    End Hour: 10:30 PM
#    End Hour: 10:30 PM
#    End Hour: 10:30 PM
#    End Hour: 10:30 PM
#    End Hour: 10:30 PM
#    End Hour: 10:30 PM
#    End Hour: 10:30 PM
# 4. Bushwick Taco Company - 839 Knickerbocker Avenue, Brooklyn
#    End Hour: 11:30 PM
#    End Hour: 11:30 PM
#    End Hour: 11:30 PM
#    End Hour: 12:00 AM
#    End Hour: 12:00 AM
#    End Hour: 12:00 AM
#    End Hour: 12:00 AM
# 5. Number One - 824 Knickerbocker Avenue, Brooklyn
#    End Hour: 11:30 PM
#    End Hour: 11:30 PM
#    End Hour: 11:30 PM
# ...
